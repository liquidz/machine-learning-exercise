% %% [markdown]
% # Linear regression with one variable
%
% ## Plotting the Data

% %%
data = load('ex1data1.txt');
X = data(:, 1);
y = data(:, 2);
m = length(y);

plot(X, y, 'rx', 'MarkerSize', 5);
ylabel('Profit in $10,000s');
xlabel('Population of City in 10,000s');

% %% [markdown]
% ## Gradient Descent
%
% $$
% \begin{eqnarray}
% J(\theta) & = & {1 \over 2m}\sum_{i=1}^m(h_\theta(x^{(i)}) - y^{(i)})^2 \\
% h_\theta(x) & = & \theta^Tx = \theta_0 + \theta_1x_1
% \end{eqnarray}
% $$

% %%
X = [ones(m, 1), data(:, 1)];   % add a column of ones to X
theta = zeros(2, 1);
iterations = 1500;
alpha = 0.01;

% %%
function J = computeCost(X, y, theta)
    m = length(y);
    pred = 0.0;
    for i=1:m,
        pred = pred + (theta' * X(i, :)' - y(i))^2;
    end;
    J = pred / (2 * m);
endfunction;

computeCost(X, y, theta)
% Out:
% ans =  32.073

% %% [markdown]
% すべての $j$ に対して $\theta_j$ を同時に更新する
%
% $$
% \theta_j := \theta_j - \alpha{1 \over m}\sum_{i=1}^m(h_\theta(x^{(i)}) - y^{(i)})x_j^{(i)}
% $$
%
% ベクトル化すると
%
% $$
% \begin{eqnarray}
% \theta & := & \theta - \alpha\delta \\
% \delta & = & {1 \over m}\sum_{i = 0}^m(h_\theta(x^{(i)}) - y^{(i)})x^{(i)}
% \end{eqnarray}
% $$

% %%
function [theta, J_history] = gradientDescent(X, y, theta, alpha, num_iters)
    m = length(y);
    J_history = zeros(num_iters, 1);
    
    for iter = 1:num_iters
        delta = 0;
        for i = 1:m,
            delta = delta + (theta' * X(i, :)' - y(i)) * X(i, :);
        end;
        delta = delta / m;
        
        theta = theta - (delta .* alpha)';

        J_history(iter) = computeCost(X, y, theta);
    end
endfunction

[optimized_theta, J_history] = gradientDescent(X, y, theta, alpha, iterations);

% %% [markdown]
% イテレーション毎の $J(\theta)$ の推移

% %%
plot(1:iterations, J_history)
axis([0 iterations])
xlabel('iteration'), ylabel('J(theta)')

% %% [markdown]
% $$
% \begin{eqnarray}
% \theta & = & \begin{pmatrix}
%     \theta_0 \\
%     \theta_1
% \end{pmatrix} , \quad
% mx & = & \begin{pmatrix}
% 1 & ... & 1 \\
% x_0 & ... & x_n
% \end{pmatrix} \\
% my & = & \theta^Tmx
% \end{eqnarray}
% $$

% %%
eX = data(:, 1);
ey = data(:, 2);

mx = 5:0.1:25;
mx = [ones(1, size(mx)(2)) ; mx];
my = optimized_theta' * mx;

plot(eX, ey, 'rx', 'MarkerSize', 3);
hold on;
plot(mx(2, :), my)

% %% [markdown]
% ## Linear regression with multi variables

% %%
data = load('ex1data2.txt');
X = data(:, 1:2);
y = data(:, 3);
m = length(y);

fprintf('First 10 examples from the dataset: \n');
fprintf('  x = [%.0f %.0f], y = %.0f \n', [X(1:10, :) y(1:10, :)]');
% Out:
% First 10 examples from the dataset:
%   x = [2104 3], y = 399900
%   x = [1600 3], y = 329900
%   x = [2400 3], y = 369000
%   x = [1416 2], y = 232000
%   x = [3000 4], y = 539900
%   x = [1985 4], y = 299900
%   x = [1534 3], y = 314900
%   x = [1427 3], y = 198999
%   x = [1380 3], y = 212000
%   x = [1494 3], y = 242500

% %% [markdown]
% ### Feature scaling
%
% #### Mean Normalization
%
% $$
% x_i := {x_i - \mu_i \over s_i}
% $$
%
% $\mu_i$ はトレーニングセット内の $x_i$ の平均値
%
% $s_i$ は feature の値の範囲で　$max - min$ もしくは標準偏差

% %%
function [X_norm, mu, sigma] = featureNormalize(X)
    X_norm = X;
    mu = zeros(1, size(X, 2));
    sigma = zeros(1, size(X, 2));
    
    for i = 1:size(X)(2),
        tmp = X(:, i);
        mu(i) = mean(tmp);
        sigma(i) = std(tmp);
        X_norm(:, i) = (tmp - mu(i)) / sigma(i);
    end;
endfunction

% %%
X = data(:, 1:2);
[X mu sigma] = featureNormalize(X);
fprintf('First 10 examples from the dataset: \n');
fprintf('  x = [%.0f %.0f], x_norm = [%.05f %.05f], y = %.0f \n', [data(:, 1:2)(1:10, :) X(1:10,:) y(1:10, :)]');

X = [ones(m, 1) X]; % add intercept term to X
% Out:
% First 10 examples from the dataset:
%   x = [2104 3], x_norm = [0.13001 -0.22368], y = 399900
%   x = [1600 3], x_norm = [-0.50419 -0.22368], y = 329900
%   x = [2400 3], x_norm = [0.50248 -0.22368], y = 369000
%   x = [1416 2], x_norm = [-0.73572 -1.53777], y = 232000
%   x = [3000 4], x_norm = [1.25748 1.09042], y = 539900
%   x = [1985 4], x_norm = [-0.01973 1.09042], y = 299900
%   x = [1534 3], x_norm = [-0.58724 -0.22368], y = 314900
%   x = [1427 3], x_norm = [-0.72188 -0.22368], y = 198999
%   x = [1380 3], x_norm = [-0.78102 -0.22368], y = 212000
%   x = [1494 3], x_norm = [-0.63757 -0.22368], y = 242500

% %%
figure;
hold on;
alphas = [0.3  0.1  0.03  0.01];
for a = alphas,
    theta = zeros(3, 1);
    [t, hist] = gradientDescent(X, y, theta, a, 50);
    plot(1:50, hist, 'color', rand(1, 3));
end;
legend('0.3', '0.1', '0.03', '0.01');

% %%
theta = zeros(3, 1);
alpha = 0.3;
num_iters = 30;

[theta, J_history] = gradientDescent(X, y, theta, alpha, num_iters);
plot(1:num_iters, J_history, '-b', 'LineWidth', 2);

% %% [markdown]
% Estimate the price of a 1650 sq-ft, 3 br house

% %%
price = [1 ([1650 3] - mu) ./ sigma] * theta;
printf('price = %d', price)
% Out:
% price = 293274

% %% [markdown]
% ### Normal Equations
%
% 正規方程式
%
% * X は m * (n+1) 次元行列
%   * n は feature 数
%   * n + 1 になっているのは $x_0$ を追加している分
% * y は m 次元ベクトル
%
% $$
% \theta = (X^TX)^{-1}X^Ty
% $$

% %%
function [theta] = normalEqn(X, y)
    theta = pinv(X' * X) * X' * y;
endfunction

data = load('ex1data1.txt');
X = data(:, 1);
X = [ones(size(X), 1), X];
y = data(:, 2);
theta = normalEqn(X, y)
% Out:
% theta =
%
%   -3.8958
%    1.1930

% %%
mx = 5:0.1:25;
mx = [ones(1, size(mx)(2)) ; mx];
my = theta' * mx;

plot(data(:, 1), data(:, 2), 'rx', 'MarkerSize', 3);
hold on;
plot(mx(2, :), my)
